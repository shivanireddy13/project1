# %%
import requests

# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.set_option('display.max_rows', None)

# %%
# !ls
# Out:
# Data Studio Project 1 Planning.docx project1_party_analysis.ipynb
# Indian_Cities-master                project1prelimanalysis.ipynb
# indiancities2.csv                   renamed indian cities.xlsx
# indiancitiesparties.csv             renamedindiancities.csv
# map.ipynb

# %%
df = pd.read_csv('indiancitiesparties.csv')

# %%
df
# Out:
#                newname        oldname  year       state_or_UT  \
# 0             Jabalpur     Jubbulpore  1947    Madhya Pradesh
# 1               Jajmau       Jajesmow  1948     Uttar Pradesh
# 2               Kanpur       Cawnpore  1948     Uttar Pradesh
# 3             Vadodara         Baroda  1974           Gujarat
# 4   Thiruvananthapuram     Trivandrum  1991        Tamil Nadu
# 5               Mumbai         Bombay  1995       Maharashtra
# 6                Kochi         Cochin  1996            Kerala
# 7              Chennai         Madras  1996        Tamil Nadu
# 8              Kolkata       Calcutta  2001       West Bengal
# 9          Medininagar     Daltonganj  2004         Jharkhand
# 10              Kadapa       Cuddapah  2005    Andhra Pradesh
# 11          Puducherry    Pondicherry  2006        Puducherry
# 12           Bengaluru      Bangalore  2007         Karnataka
# 13            Belagavi        Belgaum  2007         Karnataka
# ...

# %%
df2 = df['state_or_UT']
df2
# Out:
# 0       Madhya Pradesh
# 1        Uttar Pradesh
# 2        Uttar Pradesh
# 3              Gujarat
# 4           Tamil Nadu
# 5          Maharashtra
# 6               Kerala
# 7           Tamil Nadu
# 8          West Bengal
# 9            Jharkhand
# 10      Andhra Pradesh
# 11          Puducherry
# 12           Karnataka
# 13           Karnataka
# 14           Karnataka
# 15           Karnataka
# 16           Karnataka
# 17           Karnataka
# 18           Karnataka
# 19           Karnataka
# 20           Karnataka
# 21           Karnataka
# 22           Karnataka
# 23           Karnataka
# 24      Andhra Pradesh
# 25             Haryana
# 26       Uttar Pradesh
# 27         Chattisgarh
# 28      Madhya Pradesh
# 29              Kerala
# 30         West Bengal
# 31               Assam
# 32      Madhya Pradesh
# 33          Tamil Nadu
# 34              Kerala
# 35              Kerala
# 36              Kerala
# 37          Tamil Nadu
# 38              Kerala
# 39                 Goa
# ...

# %% [markdown]
# df2

# %%
df3 = df2[df2.value_counts()]

# %%
df3
# Out:
# 12        Karnataka
# 9         Jharkhand
# 8       West Bengal
# 4        Tamil Nadu
# 4        Tamil Nadu
# 4        Tamil Nadu
# 3           Gujarat
# 2     Uttar Pradesh
# 1     Uttar Pradesh
# 1     Uttar Pradesh
# 1     Uttar Pradesh
# 1     Uttar Pradesh
# 1     Uttar Pradesh
# 1     Uttar Pradesh
# 1     Uttar Pradesh
# 1     Uttar Pradesh
# Name: state_or_UT, dtype: object
