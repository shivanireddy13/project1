# %%
import pandas as pd
pd.options.display.max_colwidth = None
pd.set_option('display.max_rows', None)
# !ls
# Out:
# Data Studio Project 1 Planning.docx project1_party_analysis.ipynb
# Indian_Cities-master                project1prelimanalysis.ipynb
# indiancities2.csv                   renamed indian cities.xlsx
# indiancitiesparties.csv             renamedindiancities.csv

# %%
df = pd.read_csv('indiancitiesparties.csv')

# %%
df
# Out:
#                newname        oldname  year       state_or_UT  \
# 0             Jabalpur     Jubbulpore  1947    Madhya Pradesh
# 1               Jajmau       Jajesmow  1948     Uttar Pradesh
# 2               Kanpur       Cawnpore  1948     Uttar Pradesh
# 3             Vadodara         Baroda  1974           Gujarat
# 4   Thiruvananthapuram     Trivandrum  1991        Tamil Nadu
# 5               Mumbai         Bombay  1995       Maharashtra
# 6                Kochi         Cochin  1996            Kerala
# 7              Chennai         Madras  1996        Tamil Nadu
# 8              Kolkata       Calcutta  2001       West Bengal
# 9          Medininagar     Daltonganj  2004         Jharkhand
# 10              Kadapa       Cuddapah  2005    Andhra Pradesh
# 11          Puducherry    Pondicherry  2006        Puducherry
# 12           Bengaluru      Bangalore  2007         Karnataka
# 13            Belagavi        Belgaum  2007         Karnataka
# 14            Tumakuru         Tumkur  2007         Karnataka
# 15            Hubballi          Hubli  2007         Karnataka
# 16          Shivamogga        Shimoga  2007         Karnataka
# 17            Hosapete         Hospet  2007         Karnataka
# 18              Mysuru         Mysore  2007         Karnataka
# 19          Kalaburagi       Gulbarga  2007         Karnataka
# 20      Chikkamagaluru    Chikmagalur  2007         Karnataka
# 21          Vijayapura        Bijapur  2007         Karnataka
# 22             Ballari        Bellary  2007         Karnataka
# 23           Mangaluru      Mangalore  2007         Karnataka
# 24  Rajahmahendravaram    Rajahmundry  2015    Andhra Pradesh
# 25            Gurugram        Gurgaon  2016           Haryana
# 26           Prayagraj      Allahabad  2018     Uttar Pradesh
# 27          Atal Nagar     New Raipur  2018       Chattisgarh
# 28        Narmadapuram    Hoshangabad  2021    Madhya Pradesh
# 29           Alappuzha       Alleppey  1956            Kerala
# 30           Baranagar   Barahanagore  1947       West Bengal
# 31            Guwahati        Gauhati  1950             Assam
# 32              Indore         Indhur  1956    Madhya Pradesh
# 33         Kanchipuram     Conjevaram  1950        Tamil Nadu
# 34              Kannur      Cannanore  1956            Kerala
# 35              Kollam         Quilon  1956            Kerala
# 36           Kozhikode        Calicut  1956            Kerala
# 37          Kumbakonam      Kudanthai  1950        Tamil Nadu
# 38            Palakkad        Palghat  1956            Kerala
# 39              Panaji         Panjim  1961               Goa
# 40                Pune          Poona  1978       Maharashtra
# 41               Sagar         Saugor  1956    Madhya Pradesh
# 42              Shimla          Simla  1972  Himachal Pradesh
# 43          Thalassery    Tellicherry  1956            Kerala
# 44           Thanjavur        Tanjore  1950        Tamil Nadu
# 45               Thane         Tannah  1996       Maharashtra
# 46         Thoothukudi      Tuticorin  1950        Tamil Nadu
# 47            Thrissur        Trichur  1956            Kerala
# 48      Tiruchirapalli   Trichinopoly  1950        Tamil Nadu
# 49         Tirunelveli     Tinnevelly  1950        Tamil Nadu
# 50      Udhagamandalam     Ootacamund  1950        Tamil Nadu
# 51            Varanasi        Benares  1950     Uttar Pradesh
# 52          Vijayawada       Bezawada  1956    Andhra Pradesh
# 53             Waltair  Vishakapatnam  1956    Andhra Pradesh
#
#                                        party
# 0                   Indian National Congress
# 1                   Indian National Congress
# 2                   Indian National Congress
# 3                   Indian National Congress
# 4   All India Anna Dravida Munnetra Kazhagam
# 5                                  Shiv Sena
# 6                   Indian National Congress
# 7                  Dravida Munnetra Kazhagam
# 8         Communist Party of India (Marxist)
# 9                     Bharatiya Janata Party
# 10                  Indian National Congress
# 11             All India NR Congress and BJP
# 12                      Janata Dal (Secular)
# 13                      Janata Dal (Secular)
# 14                      Janata Dal (Secular)
# 15                      Janata Dal (Secular)
# 16                      Janata Dal (Secular)
# 17                      Janata Dal (Secular)
# 18                      Janata Dal (Secular)
# 19                      Janata Dal (Secular)
# 20                      Janata Dal (Secular)
# 21                      Janata Dal (Secular)
# 22                      Janata Dal (Secular)
# 23                      Janata Dal (Secular)
# 24                        Telugu Desam Party
# 25                    Bharatiya Janata Party
# 26                    Bharatiya Janata Party
# 27                    Bharatiya Janata Party
# 28                    Bharatiya Janata Party
# 29                  Indian National Congress
# 30                  Indian National Congress
# 31                  Indian National Congress
# 32                  Indian National Congress
# 33                  Indian National Congress
# 34                  Indian National Congress
# 35                  Indian National Congress
# 36                  Indian National Congress
# 37                  Indian National Congress
# 38                  Indian National Congress
# 39            Maharashtrawadi Gomantak Party
# 40                  Indian National Congress
# 41                  Indian National Congress
# 42                  Indian National Congress
# 43                  Indian National Congress
# 44                  Indian National Congress
# 45                                 Shiv Sena
# 46                  Indian National Congress
# 47                  Indian National Congress
# 48                  Indian National Congress
# 49                  Indian National Congress
# 50                  Indian National Congress
# 51                  Indian National Congress
# 52                  Indian National Congress
# 53                  Indian National Congress

# %%
df.party.value_counts()
# Out:
# Indian National Congress                    29
# Janata Dal (Secular)                        12
# Bharatiya Janata Party                       5
# Shiv Sena                                    2
# All India Anna Dravida Munnetra Kazhagam     1
# Dravida Munnetra Kazhagam                    1
# Communist Party of India (Marxist)           1
# All India NR Congress and BJP                1
# Telugu Desam Party                           1
# Maharashtrawadi Gomantak Party               1
# Name: party, dtype: int64

# %%
df.plot(kind='scatter', x='year', y='party', color='red', title='Scatter Plot')
# Out:
# <AxesSubplot: title={'center': 'Scatter Plot'}, xlabel='year', ylabel='party'>

# %%
df.party.value_counts()
# Out:
# Indian National Congress                    29
# Janata Dal (Secular)                        12
# Bharatiya Janata Party                       5
# Shiv Sena                                    2
# All India Anna Dravida Munnetra Kazhagam     1
# Dravida Munnetra Kazhagam                    1
# Communist Party of India (Marxist)           1
# All India NR Congress and BJP                1
# Telugu Desam Party                           1
# Maharashtrawadi Gomantak Party               1
# Name: party, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 dfpartypie = df[df.party.value_counts()]
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.11.0rc2/lib/python3.11/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6169     if use_interval_msg:
#    6170         key = list(key)
# -> 6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([29, 12, 5, 2, 1, 1, 1, 1, 1, 1], dtype='int64')] are in the [columns]"
